# %% [markdown]
# **Neomelanin Nanoparticle Protection of Cell-free Reactions**

# %% [markdown]
# *Figure 3*

# %% [markdown]
# Figure 3: pT7-sfGFP UVB Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_UVB_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 1.5))
sns.heatmap(data, cmap=cmap, annot=False, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_UVB_Heatmap_Paper.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7-sfGFP UVB Exposure Normalized Annotated

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_UVB_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_UVB_Heatmap_Paper_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7-sfGFP UVB Exposure FITC Noramlized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_UVB_Heatmap_FITC_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=30, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_UVB_Heatmap_Paper_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7-sfGFP Solar Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_Solar_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 1.5))
sns.heatmap(data, cmap=cmap, annot=False, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_Solar_Heatmap_Paper.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7-sfGFP Solar Exposure Noramlized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_Solar_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_Solar_Heatmap_Paper_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7-sfGFP Solar Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_Solar_Heatmap_FITC_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=30, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_Solar_Heatmap_Paper_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119-sfGFP UVB Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_UVB_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 1.5))
sns.heatmap(data, cmap=cmap, annot=False, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_UVB_Heatmap_Paper.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119-sfGFP UVB Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_UVB_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_UVB_Heatmap_Paper_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119-sfGFP UVB Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_UVB_Heatmap_FITC_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=30, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_UVB_Heatmap_Paper_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119-sfGFP Solar Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_Solar_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 1.5))
sns.heatmap(data, cmap=cmap, annot=False, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_Solar_Heatmap_Paper.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119-sfGFP Solar Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_Solar_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_Solar_Heatmap_Paper_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119-sfGFP Solar Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_Solar_Heatmap_FITC_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=30, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_Solar_Heatmap_Paper_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7 Post Lyophilization UVB Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_UVB_Lyo_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 1.5))
sns.heatmap(data, cmap=cmap, annot=False, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_UVB_Lyo_Heatmap_Paper.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7 Post Lyophilization UVB Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_UVB_Lyo_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_UVB_Lyo_Heatmap_Paper_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7-sfGFP UVB Lyo Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_UVB_Lyo_Heatmap_FITC_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=30, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_UVB_Lyo_Heatmap_Paper_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7 Lyo Solar Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_Solar_Lyo_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 1.5))
sns.heatmap(data, cmap=cmap, annot=False, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_Solar_Lyo_Heatmap_Paper.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7 Lyo Solar Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_Solar_Lyo_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_Solar_Lyo_Heatmap_Paper_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pT7-sfGFP Solar Lyo Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_T7_Solar_Lyo_Heatmap_FITC_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=30, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_T7_Solar_Lyo_Heatmap_Paper_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119 UVB Lyo Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_UVB_Lyo_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 1.5))
sns.heatmap(data, cmap=cmap, annot=False, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_UVB_Lyo_Heatmap_Paper.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119 UVB Lyo Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_UVB_Lyo_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_UVB_Lyo_Heatmap_Paper_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119-sfGFP UVB Lyo Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_UVB_Lyo_Heatmap_FITC_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=30, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_UVB_Lyo_Heatmap_Paper_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119 Solar Lyo Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_Solar_Lyo_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 1.5))
sns.heatmap(data, cmap=cmap, annot=False, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_Solar_Lyo_Heatmap_Paper.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119 Solar Lyo Exposure Noramlized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_Solar_Lyo_Heatmap_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=1.5, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_Solar_Lyo_Heatmap_Paper_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 3: pJ23119-sfGFP Solar Lyo Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = "/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_J23119_Solar_Lyo_Heatmap_FITC_Paper.xlsx"  # Replace with your actual file path
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, vmin=0, vmax=30, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_J23119_Solar_Lyo_Heatmap_Paper_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# *Figure 4*

# %% [markdown]
# Figure 4: TetR Sensor UVB Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_UVB_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 3))
sns.heatmap(data, cmap=cmap, annot=False, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_UVB_Heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Sensor UVB Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_UVB_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_UVB_Heatmap_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR UVB Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_UVB_Heatmap_FITC_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_UVB_Heatmap_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Sensor UVB Exposure Post Lyophilization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_UVB_Lyo_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 3))
sns.heatmap(data, cmap=cmap, annot=False, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_UVB_Lyo_Heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Sensor UVB Exposure Post Lyophilization Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_UVB_Lyo_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_UVB_Lyo_Heatmap_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR UVB Lyo Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_UVB_Lyo_Heatmap_FITC_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_UVB_Lyo_Heatmap_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Sensor Solar Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_Solar_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 3))
sns.heatmap(data, cmap=cmap, annot=False, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_Solar_Heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Sensor Solar Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_Solar_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_Solar_Heatmap_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Solar Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_Solar_Heatmap_FITC_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_Solar_Heatmap_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Sensor Solar Exposure Post Lyophilization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_Solar_Lyo_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 3))
sns.heatmap(data, cmap=cmap, annot=False, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_Solar_Lyo_Heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Sensor Solar Exposure Post Lyophilization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_Solar_Lyo_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_Solar_Lyo_Heatmap_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 4: TetR Solar Lyo Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_TetR_Solar_Lyo_Heatmap_FITC_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_TetR_Solar_Lyo_Heatmap_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# *Figure 5*

# %% [markdown]
# Figure 5: Fluoride Riboswitch (FRS) Sensor UVB Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_UVB_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 3))
sns.heatmap(data, cmap=cmap, annot=False, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_UVB_Heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: Fluoride Riboswitch (FRS) Sensor UVB Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_UVB_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_UVB_Heatmap_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: FRS UVB Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_UVB_Heatmap_FITC_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_UVB_Heatmap_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: Fluoride Riboswitch (FRS) Sensor UVB Exposure Post Lyophilization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_UVB_Lyo_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 3))
sns.heatmap(data, cmap=cmap, annot=False, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_UVB_Lyo_Heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: Fluoride Riboswitch (FRS) Sensor UVB Exposure Post Lyophilization Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_UVB_Lyo_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_UVB_Lyo_Heatmap_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: FRS UVB Lyo Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_UVB_Lyo_Heatmap_FITC_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_UVB_Lyo_Heatmap_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: Fluoride Riboswitch (FRS) Sensor Solar Exposure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_Solar_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 3))
sns.heatmap(data, cmap=cmap, annot=False, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_Solar_Heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: Fluoride Riboswitch (FRS) Sensor Solar Exposure Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_Solar_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_Solar_Heatmap_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: FRS Solar Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_Solar_Heatmap_FITC_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_Solar_Heatmap_FITC.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: Fluoride Riboswitch (FRS) Sensor Solar Exposure Post Lyophilization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_Solar_Lyo_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(1.5, 3))
sns.heatmap(data, cmap=cmap, annot=False, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_Solar_Lyo_Heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: Fluoride Riboswitch (FRS) Sensor Solar Exposure Post Lyophilization Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_Solar_Lyo_Heatmap_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_Solar_Lyo_Heatmap_Normalized_Values.svg", format="svg")

plt.show()

# %% [markdown]
# Figure 5: FRS Solar Lyo Exposure FITC Normalized Values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data from the Excel file
file_path = '/Users/dylan/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/117_DMN_LMI_Neomelanin_Additives/Supplementary_Information/Python_Paper/NMNP_FRS_Solar_Lyo_Heatmap_FITC_Paper.xlsx'
data = pd.read_excel(file_path, index_col=0)

# Set the font to Arial with size 9
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 9

# Define colors for the gradient
low_color = "#FFFFFF"  # White
mid_color = "#CCBFA9"  # Beige
high_color = "#5F5F52"  # Grayish

# Create a more noticeable gradient
cmap = LinearSegmentedColormap.from_list("custom_gradient", [low_color, mid_color, high_color], N=256)

# Plot the heatmap with white outlines
plt.figure(figsize=(3, 3))
sns.heatmap(data, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5, linecolor='white')  # Adds white outline

# Save the heatmap as an SVG file
plt.savefig("NMNP_FRS_Solar_Lyo_Heatmap_FITC.svg", format="svg")

plt.show()
